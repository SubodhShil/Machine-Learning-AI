# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from dotenv import load_dotenv
import pprint
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities  import GoogleSerperAPIWrapper
search = GoogleSerperAPIWrapper()

# %%
search = GoogleSerperAPIWrapper(type="news")
results = search.results("Seikh Hasina")
pprint.pp(results)
# Out:
# {'searchParameters': {'q': 'Seikh Hasina',
#                       'gl': 'us',
#                       'hl': 'en',
#                       'type': 'news',
#                       'num': 10,
#                       'page': 1,
#                       'engine': 'google'},
#  'news': [{'title': 'Bangladesh’s ousted leader Sheikh Hasina sentenced to '
#                     'death after crimes against humanity conviction',
#            'link': 'https://www.cnn.com/2025/11/17/asia/bangladesh-sheikh-hasina-verdict-intl-hnk',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '21 hours ago',
#            'source': 'CNN',
#            'position': 1},
#           {'title': 'Bangladesh’s ousted leader Sheikh Hasina sentenced to '
#                     'death in absentia',
#            'link': 'https://www.pbs.org/newshour/world/bangladeshs-ousted-leader-sheikh-hasina-sentenced-to-death-in-absentia',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '10 hours ago',
#            'source': 'PBS',
#            'position': 1},
#           {'title': '"Muhammad Yunus Wants Civil War": Sheikh Hasina\'s Aide '
#                     'After Death Penalty Verdict',
#            'link': 'https://www.ndtv.com/world-news/muhammad-yunus-wants-civil-war-sheikh-hasinas-close-aide-after-death-penalty-verdict-9654021',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '2 hours ago',
#            'source': 'NDTV',
#            'position': 1},
#           {'title': "Bangladesh's ousted prime minister sentenced to death for "
#                     'role in protest crackdown',
#            'link': 'https://www.npr.org/2025/11/17/g-s1-98112/bangladesh-sheikh-hasina-verdict',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '8 hours ago',
#            'source': 'NPR',
#            'position': 1},
#           {'title': 'Ex-Bangladesh leader Sheikh Hasina sentenced to death '
#                     'over brutal protests crackdown',
#            'link': 'https://www.bbc.com/news/live/cpwvg0w4ljrt',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '18 hours ago',
#            'source': 'BBC',
#            'position': 1},
#           {'title': 'Updates: Hasina sentenced to death, Bangladesh demands '
#                     'India extradite her',
#            'link': 'https://www.aljazeera.com/news/liveblog/2025/11/17/bangladesh-live-court-verdict-against-toppled-ex-pm-sheikh-hasina-expected',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '17 hours ago',
#            'source': 'Al Jazeera',
#            'position': 1},
#           {'title': 'Former Bangladesh Leader Sheikh Hasina Sentenced to Death '
#                     'Over Protest Crackdown',
#            'link': 'https://www.wsj.com/world/asia/former-bangladeshi-leader-sheikh-hasina-sentenced-to-death-over-violent-protest-crackdown-072de13b?gaa_at=eafs&gaa_n=AWEtsqcc6wc5H_kv1XYXlZLfHPTNFXpPF8oNcla6lOkiN6ctBdT70wQV_dNr&gaa_ts=691c02cd&gaa_sig=_5Dge2Hi4yP2smL6BE8Z2PEdnlUvmwKF1TP06sZfcKQ8CrKGRotq_EyEPhESj82lKev5TU1bH-25Rq2sldjUxQ%3D%3D',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '15 hours ago',
#            'source': 'The Wall Street Journal',
#            'position': 1},
#           {'title': 'Ousted Bangladesh PM Sheikh Hasina sentenced to death for '
#                     'crimes against humanity',
#            'link': 'https://www.theguardian.com/world/2025/nov/17/ousted-bangladesh-pm-sheikh-hasina-found-guilty-of-crimes-against-humanity',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '20 hours ago',
#            'source': 'The Guardian',
#            'position': 1},
#           {'title': 'Bangladesh sentences Sheikh Hasina to death over students '
#                     'crackdown',
#            'link': 'https://www.nbcnews.com/world/asia/bangladesh-sentences-sheikh-hasina-death-students-crackdown-rcna244320',
#            'section': 'Ex-Bangladesh prime minister Sheikh Hasina sentenced to '
#                       'death',
#            'date': '20 hours ago',
#            'source': 'NBC News',
#            'position': 1},
#           {'title': 'Bangladesh prosecution seeks death penalty for ex-PM '
#                     'Sheikh Hasina over protest killings',
#            'link': 'https://apnews.com/article/bangladesh-yunus-hasina-trial-death-penalty-c50ee429eefcd964b6bc36b67c93d03b',
#            'snippet': 'Bangladeshi Nobel Peace Prize laureate Muhammad Yunus '
#                       'took over as the head of an interim government three '
#                       "days after Hasina's fall. Yunus vowed...",
#            'date': '1 month ago',
#            'source': 'AP News',
#            'imageUrl': 'data:image/jpeg;base64,...',
#            'position': 2}],
#  'credits': 1}
